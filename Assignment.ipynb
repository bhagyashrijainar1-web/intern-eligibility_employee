# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyashrijainar1-web/intern-eligibility_employee/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("=== DIGITAL DREAMS EMPLOYEE MANAGEMENT SYSTEM ===")

user = input("Enter Username: ")
pwd = input("Enter Password: ")

if login(user, pwd):
    print("Login Successful!")

    employee = register_employee()
    if employee:
        present_days = attendance_management()
        calculate_salary(employee[4], present_days)
        performance_evaluation()
else:
    print("Access Denied")
# Out:
# === DIGITAL DREAMS EMPLOYEE MANAGEMENT SYSTEM ===
# Enter Username: dd_admin
# Enter Password: 123
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3015838507.py in <cell line: 0>()
#       4 pwd = input("Enter Password: ")
#       5
# ----> 6 if login(user, pwd):
#       7     print("Login Successful!")
#       8
#
# NameError: name 'login' is not defined
